# %%
import pandas as pd

# %%
dataset = pd.read_csv(
    r"C:\Users\LENOVO\Machine Learning\DataCollection\climate_change_data_merged1.csv"
)
dataset.head()
# Out:
#       Date          Location        Country  Temperature  CO2 Emissions  \
# 0  00:00.0   New Williamtown         Latvia    10.688986     403.118902
# 1  09:43.3      North Rachel   South Africa    13.814430     396.663499
# 2  19:26.5  West Williamland  French Guiana    27.323718     451.553155
# 3  29:09.8       South David        Vietnam    12.309581     422.404984
# 4  38:53.0    New Scottburgh        Moldova    13.210885     410.472999
#
#    Sea Level Rise  Precipitation   Humidity  Wind Speed  Unnamed: 9  \
# 0        0.717506      13.835237  23.631256   18.492026         NaN
# 1        1.205715      40.974084  43.982946   34.249300         NaN
# 2       -0.160783      42.697931  96.652600   34.124261         NaN
# 3       -0.475931       5.193341  47.467938    8.554563         NaN
# 4        1.135757      78.695280  61.789672    8.001164         NaN
#
#    INDICATOR SUBJECT   MEASURE     Value  YEARS FREQUENCY
# 0  CROPYIELD    RICE  TONNE_HA  8.314607   1990         A
# ...

# %%
dataset.shape
# Out:
# (20566, 16)
